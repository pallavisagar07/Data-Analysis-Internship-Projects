# %% [markdown]
# Netflix Data Cleaning & Preparation

# %%
#Step 1.Import the dataset using Python and Pandas

import pandas as pd
df=pd.read_excel(r"C:\Users\Dell\Downloads\Dataset.csv.xlsx")
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States 2021-09-25          2020  PG-13    90 min
# 1         France 2021-09-24          2021  TV-MA  1 Season
# 2  United States 2021-09-24          2021  TV-MA  1 Season
# 3         Brazil 2021-09-22          2021  TV-PG    91 min
# 4  United States 2021-09-24          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
#Understand dataset
print(df.shape)
# Out:
# (8790, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   datetime64[ns]
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 686.8+ KB

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
#Step2.Identify and handle missing values
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %% [markdown]
# Missing Value Analysis: The dataset was checked for missing values using isnull().sum(). No missing values were found in any column.

# %%
#Step3.Remove duplicate records and formatting inconsistencies

df.duplicated().sum()                  #check duplicate records
# Out:
# np.int64(0)

# %%
df.dtypes                      #check data type
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# dtype: object

# %%
#Step4.Standardize columns such as Country,Rating and type
print(df['type'].unique())
# Out:
# ['Movie' 'TV Show']

# %%
print(df['rating'].unique())
# Out:
# ['PG-13' 'TV-MA' 'TV-PG' 'TV-14' 'TV-Y7' 'TV-Y' 'PG' 'TV-G' 'R' 'G'
#  'NC-17' 'NR' 'TV-Y7-FV' 'UR']

# %%
print(df['country'].unique()[:20])
# Out:
# ['United States' 'France' 'Brazil' 'United Kingdom' 'India' 'Germany'
#  'Pakistan' 'Not Given' 'China' 'South Africa' 'Japan' 'Nigeria' 'Spain'
#  'Philippines' 'Australia' 'Argentina' 'Canada' 'Hong Kong' 'Italy'
#  'New Zealand']

# %% [markdown]
# Categorical columns (type, rating, country) were checked for formatting inconsistencies and unnecessary whitespace. No major inconsistencies were found.

# %%
# Step 5: Export the cleaned dataset

df.to_csv("netflix_cleaned.csv", index=False)
print("Cleaned dataset exported successfully!")
# Out:
# Cleaned dataset exported successfully!
